# %% [markdown]
# # Sorting Data

# %%
import pandas as pd

# %%
df = pd.DataFrame({"3PA":{"0.0":11.1,"1.0":8.1,"2.0":7.9,"3.0":7.7,"4.0":4.7},"3PM":{"0.0":5.1,"1.0":3.6,"2.0":3.3,"3.0":3.5,"4.0":2.1},"League":{"0.0":"NBA","1.0":"NBA","2.0":"NBA","3.0":"NBA","4.0":"NBA"},"PTS":{"0.0":32.0,"1.0":23.8,"2.0":24.0,"3.0":22.9,"4.0":14.7},"Team":{"0.0":"Golden State","1.0":"Golden State","2.0":"Golden State","3.0":"Golden State","4.0":"Golden State"},"year":{"0.0":"2015-2016","1.0":"2014-2015","2.0":"2013-2014","3.0":"2012-2013","4.0":"2011-2012"},"%3 PTS":{"0.0":0.478125,"1.0":0.4537815126,"2.0":0.4125,"3.0":0.4585152838,"4.0":0.4285714286},"per3":{"0.0":47.8125,"1.0":45.3781512605,"2.0":41.25,"3.0":45.8515283843,"4.0":42.8571428571}})

# %%
df.reindex()
# Out:
#        %3 PTS   3PA  3PM League   PTS          Team       per3       year
# 0.0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016
# 1.0  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 2.0  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 3.0  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 4.0  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012

# %%
df
# Out:
#        %3 PTS   3PA  3PM League   PTS          Team       per3       year
# 0.0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016
# 1.0  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 2.0  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 3.0  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 4.0  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012

# %%
df.at["5.0",'year']='2016-2017'

# %%
df
# Out:
#        %3 PTS   3PA  3PM League   PTS          Team       per3       year
# 0.0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016
# 1.0  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 2.0  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 3.0  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 4.0  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012
# 5.0       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017

# %%
df.sort_values('year')
# Out:
#        %3 PTS   3PA  3PM League   PTS          Team       per3       year
# 4.0  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012
# 3.0  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 2.0  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 1.0  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 0.0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016
# 5.0       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017

# %%
df.sort_values('year', ascending=False)
# Out:
#        %3 PTS   3PA  3PM League   PTS          Team       per3       year
# 5.0       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017
# 0.0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016
# 1.0  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 2.0  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 3.0  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 4.0  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012

# %%
df.sort_values('PTS')
# Out:
#        %3 PTS   3PA  3PM League   PTS          Team       per3       year
# 4.0  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012
# 3.0  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 1.0  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 2.0  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 0.0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016
# 5.0       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017

# %%
df.sort_values('PTS', na_position='first')
# Out:
#        %3 PTS   3PA  3PM League   PTS          Team       per3       year
# 5.0       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017
# 4.0  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012
# 3.0  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 1.0  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 2.0  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 0.0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016

# %%
df['GP'] = [25, 80, 78,78, 26, None]

# %%
df
# Out:
#        %3 PTS   3PA  3PM League   PTS          Team       per3       year  \
# 0.0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016
# 1.0  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 2.0  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 3.0  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 4.0  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012
# 5.0       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017
#
#        GP
# 0.0  25.0
# 1.0  80.0
# 2.0  78.0
# 3.0  78.0
# 4.0  26.0
# 5.0   NaN

# %%
df.sort_values(['GP', 'PTS'])
# Out:
#        %3 PTS   3PA  3PM League   PTS          Team       per3       year  \
# 0.0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016
# 4.0  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012
# 3.0  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 2.0  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 1.0  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 5.0       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017
#
#        GP
# 0.0  25.0
# 4.0  26.0
# 3.0  78.0
# 2.0  78.0
# 1.0  80.0
# 5.0   NaN

# %%
df.sort_values(['GP', 'PTS'], ascending=[False, False])
# Out:
#        %3 PTS   3PA  3PM League   PTS          Team       per3       year  \
# 1.0  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 2.0  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 3.0  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 4.0  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012
# 0.0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016
# 5.0       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017
#
#        GP
# 1.0  80.0
# 2.0  78.0
# 3.0  78.0
# 4.0  26.0
# 0.0  25.0
# 5.0   NaN

# %%
df.sort_values(['GP', 'PTS'], ascending=[False, True])
# Out:
#        %3 PTS   3PA  3PM League   PTS          Team       per3       year  \
# 1.0  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 3.0  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 2.0  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 4.0  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012
# 0.0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016
# 5.0       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017
#
#        GP
# 1.0  80.0
# 3.0  78.0
# 2.0  78.0
# 4.0  26.0
# 0.0  25.0
# 5.0   NaN

# %% [markdown]
# ##  Sort Index

# %%
df.sort_index()
# Out:
#        %3 PTS   3PA  3PM League   PTS          Team       per3       year  \
# 0.0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016
# 1.0  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 2.0  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 3.0  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 4.0  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012
# 5.0       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017
#
#        GP
# 0.0  25.0
# 1.0  80.0
# 2.0  78.0
# 3.0  78.0
# 4.0  26.0
# 5.0   NaN

# %%
df.sort_index(ascending=False)
# Out:
#        %3 PTS   3PA  3PM League   PTS          Team       per3       year  \
# 5.0       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017
# 4.0  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012
# 3.0  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 2.0  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 1.0  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 0.0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016
#
#        GP
# 5.0   NaN
# 4.0  26.0
# 3.0  78.0
# 2.0  78.0
# 1.0  80.0
# 0.0  25.0

# %%
df.sort_index(axis=0)
# Out:
#        %3 PTS   3PA  3PM League   PTS          Team       per3       year  \
# 0.0  0.478125  11.1  5.1    NBA  32.0  Golden State  47.812500  2015-2016
# 1.0  0.453782   8.1  3.6    NBA  23.8  Golden State  45.378151  2014-2015
# 2.0  0.412500   7.9  3.3    NBA  24.0  Golden State  41.250000  2013-2014
# 3.0  0.458515   7.7  3.5    NBA  22.9  Golden State  45.851528  2012-2013
# 4.0  0.428571   4.7  2.1    NBA  14.7  Golden State  42.857143  2011-2012
# 5.0       NaN   NaN  NaN    NaN   NaN           NaN        NaN  2016-2017
#
#        GP
# 0.0  25.0
# 1.0  80.0
# 2.0  78.0
# 3.0  78.0
# 4.0  26.0
# 5.0   NaN

# %%
df.sort_index(axis=1)
# Out:
#        %3 PTS   3PA  3PM    GP League   PTS          Team       per3  \
# 0.0  0.478125  11.1  5.1  25.0    NBA  32.0  Golden State  47.812500
# 1.0  0.453782   8.1  3.6  80.0    NBA  23.8  Golden State  45.378151
# 2.0  0.412500   7.9  3.3  78.0    NBA  24.0  Golden State  41.250000
# 3.0  0.458515   7.7  3.5  78.0    NBA  22.9  Golden State  45.851528
# 4.0  0.428571   4.7  2.1  26.0    NBA  14.7  Golden State  42.857143
# 5.0       NaN   NaN  NaN   NaN    NaN   NaN           NaN        NaN
#
#           year
# 0.0  2015-2016
# 1.0  2014-2015
# 2.0  2013-2014
# 3.0  2012-2013
# 4.0  2011-2012
# 5.0  2016-2017

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#           year       per3          Team   PTS League    GP  3PM   3PA  \
# 0.0  2015-2016  47.812500  Golden State  32.0    NBA  25.0  5.1  11.1
# 1.0  2014-2015  45.378151  Golden State  23.8    NBA  80.0  3.6   8.1
# 2.0  2013-2014  41.250000  Golden State  24.0    NBA  78.0  3.3   7.9
# 3.0  2012-2013  45.851528  Golden State  22.9    NBA  78.0  3.5   7.7
# 4.0  2011-2012  42.857143  Golden State  14.7    NBA  26.0  2.1   4.7
# 5.0  2016-2017        NaN           NaN   NaN    NaN   NaN  NaN   NaN
#
#        %3 PTS
# 0.0  0.478125
# 1.0  0.453782
# 2.0  0.412500
# 3.0  0.458515
# 4.0  0.428571
# 5.0       NaN
