# %%
import pandas as pd

# %%
temp3 = pd.Series([50, 60, 90, 95, 60], index=['T', 'W', 'Th', 'S', 'M'])

# %% [markdown]
# ## Plotting

# %%
temp3

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
temp3.plot()

# %%
temp3.plot(style='k')

# %%
temp3.plot(style='r')

# %%
temp3.plot.bar()

# %%
temp3.plot.barh()

# %%
temp3.plot.box()

# %%
temp3.plot.hist()

# %%
temp3.plot.kde()

# %%
temp3.plot.pie()

# %%
ax = temp3.plot.kde()
ax.set_xlabel('temps')
ax.set_ylabel('percent')
# Out:
# Text(0,0.5,'percent')
